# %%
import numpy as np
import PIL

# %%
path = "C:/Users/Austin Paulraj/Desktop/Austin/Dataset/General/Eyes/Raw_Lineart/extracted_images"

# %%
img = PIL.open(os.path.join(folder,filename)).convert('RGB')
img
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 img = PIL.open(os.path.join(folder,filename)).convert('RGB')
#       2 img
#
# AttributeError: module 'PIL' has no attribute 'open'
