# %%
import photoshop.api as ps
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import os
import pandas as pd
import shutil

# %%
ds_path = "C:/Users/Austin Paulraj/Desktop/Austin/Dataset/Characters"

# %%
def collect_data(ds_path):
    ds = {"path":[], "filename":[], "image_name":[]}
    for source in os.listdir(ds_path):
        #print(source)
        source_path = os.path.join(ds_path,source)
        
        for character in os.listdir(source_path):
            #print(character)
            character_path = os.path.join(source_path,character)
            
            ds["path"].append(character_path)
            file_aux = []
            img_aux = []
            for art_type in os.listdir(character_path):
                #print(art_type)
                if art_type != "Lineart":
                    art_path = os.path.join(character_path,art_type)
                    
                    
                    

                    for image_filename in os.listdir(art_path):
                        file_aux.append(os.path.join(art_type,image_filename))
                        img_aux.append(image_filename)
                
            ds["filename"].append(file_aux)
            ds["image_name"].append(img_aux)
    return ds

# %%
ds = collect_data(ds_path)
print(ds["path"][0])
print(ds["filename"][0])
print(ds["image_name"][0])
print(len(ds["path"]))
print(len(ds["filename"]))
print(len(ds["image_name"]))
print(len(ds["image_name"][0]))
# Out:
# C:/Users/Austin Paulraj/Desktop/Austin/Dataset/Characters\Onepiece\Luffy
# ['Concept_Art\\0314536300c95193276277e2606f32f9.jpg', 'Concept_Art\\0497d2cdc288dd899ade6a6581293fe9.jpg', 'Concept_Art\\0791fbac86852df6e96d402b69036fb4.jpg', 'Concept_Art\\0f26156a368889e2f48a6d97068ae029.jpg', 'Concept_Art\\13490a102a3456b92ee290383fada416.jpg', 'Concept_Art\\1cefb4c18b297ae158cec0a20fe1bd17.jpg', 'Concept_Art\\1db2ccb9d691c40c52555ab103c98eff.jpg', 'Concept_Art\\28672ab4bbf7924de6a484e8a6b63c03.jpg', 'Concept_Art\\40a7671ffcaf0b19077195df510c6059.jpg', 'Concept_Art\\451e9d563ef8c584080dc3161fe616fc.jpg', 'Concept_Art\\4c3a6d295344b5cd1a698bb507ee26f4.jpg', 'Concept_Art\\680d2e392c4a03e8883f6ffee5ee68f0.jpg', 'Concept_Art\\7bfd3a6688634bed7c32da0004ca085c.jpg', 'Concept_Art\\83ee100a8f0361a9a924c8f742a21ec1.jpg', 'Concept_Art\\9a491e66af382433e37e80d670360a7c.jpg', 'Concept_Art\\9d16ddef14c843e0e92ef834acf26b6b.jpg', 'Concept_Art\\a44bbb8ee20fdf07611921a557c69ac7.jpg', 'Concept_Art\\a5c00f5b3d50376030c02e755b5dea34.jpg', 'Concept_Art\\b7857138b9f2db1030a423d999f20df2.jpg', 'Concept_Art\\b94a3dba883091f8a932447966905f1b.jpg', 'Concept_Art\\bb43e507089801a7d01469d8d1897b9f.jpg', 'Concept_Art\\bfa22dd5bd2c94d174a2b477cfaae6c2.jpg', 'Concept_Art\\c03ee3b3893d8ebe41e64605b9a2fd7d.jpg', 'Concept_Art\\d878b096e4e7905793d90aca92a4922a.jpg', 'Concept_Art\\e17644049b333d52792264fc1de17760.jpg', 'Concept_Art\\ec93f161bc079d88b1619a7d41bd4223.jpg']
# ['0314536300c95193276277e2606f32f9.jpg', '0497d2cdc288dd899ade6a6581293fe9.jpg', '0791fbac86852df6e96d402b69036fb4.jpg', '0f26156a368889e2f48a6d97068ae029.jpg', '13490a102a3456b92ee290383fada416.jpg', '1cefb4c18b297ae158cec0a20fe1bd17.jpg', '1db2ccb9d691c40c52555ab103c98eff.jpg', '28672ab4bbf7924de6a484e8a6b63c03.jpg', '40a7671ffcaf0b19077195df510c6059.jpg', '451e9d563ef8c584080dc3161fe616fc.jpg', '4c3a6d295344b5cd1a698bb507ee26f4.jpg', '680d2e392c4a03e8883f6ffee5ee68f0.jpg', '7bfd3a6688634bed7c32da0004ca085c.jpg', '83ee100a8f0361a9a924c8f742a21ec1.jpg', '9a491e66af382433e37e80d670360a7c.jpg', '9d16ddef14c843e0e92ef834acf26b6b.jpg', 'a44bbb8ee20fdf07611921a557c69ac7.jpg', 'a5c00f5b3d50376030c02e755b5dea34.jpg', 'b7857138b9f2db1030a423d999f20df2.jpg', 'b94a3dba883091f8a932447966905f1b.jpg', 'bb43e507089801a7d01469d8d1897b9f.jpg', 'bfa22dd5bd2c94d174a2b477cfaae6c2.jpg', 'c03ee3b3893d8ebe41e64605b9a2fd7d.jpg', 'd878b096e4e7905793d90aca92a4922a.jpg', 'e17644049b333d52792264fc1de17760.jpg', 'ec93f161bc079d88b1619a7d41bd4223.jpg']
# 31
# 31
# 31
# 26

# %%
for c in ds["path"]:
    target = os.path.join(c,"Lineart")
    if not os.path.exists(target):
        os.makedirs(target)

# %%
def apply_action_and_save(path, filename, image_name):
    lineart_name = "Lineart/" + image_name
    jpg_file = os.path.join(path, lineart_name)
    #if not os.path.exists(jpg_file):
    app = ps.Application()
    doc = app.load(os.path.join(path,filename))
    idPly = app.charIDToTypeID("Ply ")
    desc8 = ps.ActionDescriptor()
    idnull = app.charIDToTypeID("null")

    ref3 = ps.ActionReference()
    idActn = app.charIDToTypeID("Actn")
    ref3.putName(idActn, "remove_bg")
    idASet = app.charIDToTypeID("ASet")
    ref3.PutName(idASet, "Default Actions")
    desc8.putReference(idnull, ref3)
    app.executeAction(idPly, desc8, ps.DialogModes.DisplayNoDialogs)

    ref3.putName(idActn, "remove_bg")
    desc8.putReference(idnull, ref3)
    app.executeAction(idPly, desc8, ps.DialogModes.DisplayNoDialogs)


    #options = ps.PNGSaveOptions()
    
    #doc.saveAs(jpg_file, options, asCopy=True)
    input("done?")
    doc.close()

# %%
ds["path"][0]
# Out:
# 'C:/Users/Austin Paulraj/Desktop/Austin/Dataset/Characters\\Onepiece\\Luffy'

# %%
ds["filename"][0][0]
# Out:
# 'Concept_Art\\0314536300c95193276277e2606f32f9.jpg'

# %%
ds["image_name"][0][0]
# Out:
# '0314536300c95193276277e2606f32f9.jpg'

# %%
for i in range(len(ds["path"])):
    in_path = ds["path"][i]
    for j in range(len(ds["filename"][i])):
        in_file = ds["filename"][i][j]
        in_name = ds["image_name"][i][j]
        apply_action_and_save(in_path,in_file,in_name)
        break
    break
# Out:
# ---------------------------------------------------------------------------
# COMError                                  Traceback (most recent call last)
# Cell In[17], line 6
#       4     in_file = ds["filename"][i][j]
#       5     in_name = ds["image_name"][i][j]
# ----> 6     apply_action_and_save(in_path,in_file,in_name)
#       7     break
#       8 break
#
# Cell In[16], line 17, in apply_action_and_save(path, filename, image_name)
#      15 ref3.PutName(idASet, "Default Actions")
#      16 desc8.putReference(idnull, ref3)
# ---> 17 app.executeAction(idPly, desc8, ps.DialogModes.DisplayNoDialogs)
#      19 ref3.putName(idActn, "remove_bg")
#      20 desc8.putReference(idnull, ref3)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\photoshop\api\application.py:385, in Application.executeAction(self, event_id, descriptor, display_dialogs)
#     384 def executeAction(self, event_id, descriptor, display_dialogs=2):
# --> 385     return self.app.executeAction(event_id, descriptor, display_dialogs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\comtypes\client\lazybind.py:160, in Dispatch.__getattr__.<locals>.caller(*args)
#     159 def caller(*args):
# --> 160     return self._comobj._invoke(descr.memid, descr.invkind, 0, *args)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\comtypes\automation.py:852, in IDispatch._invoke(self, memid, invkind, lcid, *args)
#     849         dp.rgdispidNamedArgs = pointer(DISPID(DISPID_PROPERTYPUT))
#     850     dp.rgvarg = array
# --> 852 self.__com_Invoke(  # type: ignore
#     853     memid, riid_null, lcid, invkind, dp, var, None, argerr
#     854 )
#     855 return var._get_value(dynamic=True)
#
# COMError: (-2147213497, None, (None, None, None, 0, None))
