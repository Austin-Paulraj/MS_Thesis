# %%
import sys
import pickle
import photoshop.api as ps
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import os
import pandas as pd
import shutil
from IPython.display import clear_output

# %%
concat_ds = "D://MS_Thesis_Data//Kaggle_Segmentation_Datasets//concatenated"
temp = "C://Austin//Projects//MS_Thesis_Data//temp"

# %%
img_ds = os.path.join(concat_ds, "images")
mak_ds = os.path.join(concat_ds, "masks")

images = []

for name in os.listdir(img_ds)[5280:]:
    main_img = Image.open(os.path.join(img_ds, name))
    #mask_img = Image.open(os.path.join(mak_ds, name))

    images.append(main_img)

    main_img.save(os.path.join(temp, "temp_main.png"))
    #mask_img.save(os.path.join(temp, "temp_mask.png"))

    #main_img = Image.open(os.path.join(temp, "temp_main.png"))
    #mask_img = Image.open(os.path.join(temp, "temp_main.png"))

    #mask_img = mask_img.convert("L")

    #masked = main_img.putalpha(mask_img)

# %%
n=-1

# %%
n += 1

# %%
name
# Out:
# '5_00270.png'
